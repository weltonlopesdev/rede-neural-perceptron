# %% [markdown]
# <a href="https://colab.research.google.com/github/weltonlopesdev/rede-neural-perceptron/blob/main/Redes_Neurais_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Redes neurais(conceito)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > input layer: camada de entrada
#
# > output layer: camada de saida
#
# > hidden layer: camada oculta
#
# A informação é passada através de cada camada, com a saída da camada anterior fornecendo entrada para a próxima camada. A primeira camada em uma rede é chamada de camada de entrada, enquanto a última é chamada de camada de saída. Todas as camadas entre as duas são referidas como camadas ocultas. Cada camada é tipicamente um algoritmo simples e uniforme contendo um tipo de função de ativação.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Perceptron é um neuronio artificial, segue abaixo utilizando em python**
#
# ![image.png](data:image/png;base64,...)

# %%
#exemplo basico de MLP perceptron usando a biblioteca sklearn

from sklearn.neural_network import MLPClassifier

X = [[0., 0.], [0., 1.], [1., 0.]]
y = [0., 1., 1.]

clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(2), random_state=1)
clf.fit(X, y) #treino
clf.predict([[1.,1.]])#aplicação teste
# Out:
# array([1.])

# %% [markdown]
# Como funciona?
#
#
#
# > multiplica o x1(ENTRADA 1) * w1(PESO1) e x2(ENTRADA2) * w2(PESO2) e depois soma os resultados
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Apos passa pela função de ativação para depois me apontar as predições
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **CALCULO**
#
#
#
# > x1 = 1
#
# > x2 = 2
#
# > w1 = -0.55
#
# > w2 = 0.1
#
# ![image.png](data:image/png;base64,...) = 0.35

# %% [markdown]
# **FUNÇÃO DE ATIVAÇÃO**
#
#
# ![image.png](data:image/png;base64,...)  = -0.35
#
#
#
#
#
#
#
#
# > SENDO ASSIM A MINHA PREDIÇÃO É = 0
#
#
#
#
# para iniciar o PERCEPTRON é necessário iniciar com um conjunto de dados supervisionado(dados de entrada)
# perceptron para fazer as predições: 1 - passar pelo calculo 2 - fazer as predições
# calcular os erros(loss) e atualizar os pesos

# %%
import numpy as np

class Perceptron:
    def __init__(self, input_size):
        self.weights = np.zeros(input_size)
        self.bias = 0

    def predict(self, inputs):
        activation = np.dot(inputs, self.weights) + self.bias
        return np.where(activation >= 0, 1, 0)

    def train(self, training_inputs, labels, epochs):
        for _ in range(epochs):
            for inputs, label in zip(training_inputs, labels):
                prediction = self.predict(inputs)
                self.weights += (label - prediction) * inputs
                self.bias += (label - prediction)

# Exemplo de uso
training_inputs = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
labels = np.array([0, 0, 0, 1])

perceptron = Perceptron(input_size=2)
perceptron.train(training_inputs, labels, epochs=10)

# Testando o Perceptron treinado
test_inputs = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
for inputs in test_inputs:
    print(f"Input: {inputs} Predict: {perceptron.predict(inputs)}")
# Out:
# Input: [0 0] Predict: 0
# Input: [0 1] Predict: 0
# Input: [1 0] Predict: 0
# Input: [1 1] Predict: 1
